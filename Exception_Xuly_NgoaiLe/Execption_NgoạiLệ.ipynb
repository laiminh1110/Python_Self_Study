# %%
"""
Ngoại lệ là gì? (exeption?)
Tầm quan trọng của xử lý ngoại lệ
tại sao phải xử lý ngoại lệ
lệnh Assert
lệnh Try

"""

# %%
# ví dụ

def tinh(x, y):
    try:
         ket_qua = x/(x-y)
         return ket_qua
    except ZeroDivisionError:
        return "Lỗi chia cho 0, thử lại!"

tinh(8,8)
# Out:
# 'Lỗi chia cho 0, thử lại!'

# %%
## assert trong xử lý exeption


x = float(input("Nhập khoảng cách x:"))
y = float(input("Nhập khoảng cách y:"))

assert x>=0 and y>=0, 'Khoảng cách vô lý'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 7
#       3
#       4 x = float(input("Nhập khoảng cách x:"))
#       5 y = float(input("Nhập khoảng cách y:"))
#       6
# ----> 7 assert x>=0 and y>=0, 'Khoảng cách vô lý'
#       8
#       9
#
# AssertionError: Khoảng cách vô lý

# %%
## try - exeption - else
## try - exception - finally
## try - finaly
## tự tạo custom exeption
