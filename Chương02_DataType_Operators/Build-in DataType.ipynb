# %% [markdown]
# ## Đây là các kiểu dựng sẳn được hỗ trợ trong PyThon

# %%
# Numeric Category: int,float,complex( số phức)

# %%
# Sequence Category: str, list, range, tuple

# %%
# Mapping Category : Dict(key:value)

# %%
# Set Category: Set, Frozenset

# %%
# Boolean Category: Bool

# %%
# None Category: NoneType

# %%
# Binary Category: bytes, bytearray, memoryview

# %% [markdown]
# ## 1. Numeric - int - float - int() - float()

# %%
so_nguyen = 10
so_thuc = 3.5
print(so_nguyen)
print(so_thuc)
# Out:
# 10
# 3.5

# %%
luong_co_ban = 10_000_000
luong_hang_thang = 10e6
print(luong_co_ban)
# Out:
# 10000000

# %%
# ép kiểu
int(10.6)
float(20)
# Out:
# 20.0

# %%
# Kiểu số hỗ trợ thực hiện các loại toán tử sau:

10+3
10-3
10*3
10/3 # 3.3333333333333335
10//3 # 3
10%3  # 1

pow(2,3) # luỹ thừa
2**3 # Luy thừa

abs(-9) # lấy tuyệt
round(10/3,3)
# Out:
# 3.333

# %%
import math as mt
abc = mt.sqrt(10)

# %% [markdown]
# ## 2.Kiểu chuổi - str - str()

# %%
#index+   012345 789 11
ho_ten = "Nguyễn Văn A"
#index- -12           -1

ho_ten[-12]
# Out:
# 'N'

# %%
ht = 'Nguyễn Văn B'
ht.split()
# Out:
# ['Nguyễn', 'Văn', 'B']

# %%
print(ho_ten)
print(ht)

# %%
email = "info@citd.edu.vn"
email.split("@")
email.split(".")
# Out:
# ['info@citd', 'edu', 'vn']

# %%
char = ['P','y','t','h','o','n']
result = "".join(char)
result
# Out:
# 'Python'

# %% [markdown]
# ## 3. Kiểu danh sách - list - list() -  ko phải array

# %%
ds1 = [
    "Nguyễn Văn A",
    6.8,
    80
]

type(ds1)
# Out:
# list

# %%
#index+        0        1    2
ds2 = ["Nguyễn Văn B", 8.1, 90]
#index-      -3.        -2   -1
print(type(ds2))

# ds2[-2]
# Out:
# <class 'list'>

# %%
# dùng medthod thêm 1 hoặc nhiều phần tử

# %%
d = [1,5,8,'abc',9,5,8]
d.append(9)
d.extend([10,11,12])
d.pop() # defaut index = -1 lấy ra
d
# Out:
# [1, 5, 8, 'abc', 9, 5, 8, 9, 10, 11]

# %%
d = [1,5,8,'abc',9,5,8]
d[3] = 9        # lấy thông tin và thay đổi thông tin - getter-setter
d
# Out:
# [1, 5, 8, 9, 9, 5, 8]

# %% [markdown]
# ## 4. Kiểu Tuple - tuple()

# %%
("Nguyễn Văn A", 6.9,89)

# %%
#index+     0        1    2
t2 = ("Nguyễn Văn B", 6.9, 89)
#index-    -3.       -2   -1

# %%
t3 = "Nguyễn Văn C", 6.7, 80
t4 = ()
t5 = (5,)

# %%
t2[0]
# t2[0] = "hfjksdhf".  # TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 t2[0]
# ----> 2 t2[0] = "hfjksdhf"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Ghi chú để xem lại

# %%
"""
- Tất
ghi chú:
 . Kiểu số
 . Kiểu chuỗi ""     index + -          có getter/setter
 . Kiểu List  []     index + -          có getter/setter
 . Kiểu Tuple ()     index + -          có getter/ko setter








"""
